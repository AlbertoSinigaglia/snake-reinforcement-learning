# %% [markdown]
# # Snake

# %%
import keras.optimizers
from environments import *
from IPython.display import clear_output
from  tqdm import trange
import matplotlib.pyplot as plt
import os
from replay_memory import *
from models import *
import json
import random
random.seed(0)
np.random.seed(0)
tf.random.set_seed(0)

# %%
LOAD_FROM_MEMORY = False

# %% [markdown]
# ## Environment definition

# %%
# %matplotlib inline
def get_env(n=1000):
    return Walls25x25SnakeEnvironment(n)
env_ = get_env()
GAMMA = .9
ITERATIONS = 100000
EPSILON = 0.1
LAMBDA_VALUE = 0.
LAMBDA_AGENT = 0.
RESET_EVERY_N = 100
# 10 random iterations, 100 elements from each of them
replay_memory = ReplayMemoryFast(1000, 10, 100)
#  ALPHA = 0.1

fig,axs=plt.subplots(1,min(len(env_.boards), 5), figsize=(10,3))
for ax, board in zip(axs, env_.boards):
    ax.get_yaxis().set_visible(False)
    ax.get_xaxis().set_visible(False)
    ax.imshow(board, origin="lower")

# %% [markdown]
# ## Demo

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
demo_env = get_env(1000)
def animate(_):
    probs = tf.convert_to_tensor([[.25]*4]*demo_env.n_boards)
    actions = tf.random.categorical(tf.math.log(probs),1)
    demo_env.move(actions)
    for board, image in zip(demo_env.boards[:len(images)], images):
        image.set_data(board)
    return images

# %%
fig, axs = plt.subplots(1,4, figsize=(10,3))
images = []
for b, ax in zip(demo_env.boards, axs.flatten()):
    ax.get_yaxis().set_visible(False)
    ax.get_xaxis().set_visible(False)
    images.append(ax.imshow(b, origin="lower"))
anim = FuncAnimation(fig, animate, interval=30)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Model

# %%
class BoltzmannPolicy:
    def __init__(self):
        self.temperature_mu = tf.Variable(1., name="mu")
        self.temperature_log_sigma_square = tf.Variable(0., name="sigma")
    def sample(self, q_values):
        probs, temperature = self.get_probs(q_values)
        return tf.random.categorical(
            np.log(probs), 1
        ).numpy(), temperature
    def get_probs(self, q_values):
        temperature = np.random.normal(self.temperature_mu, np.exp(self.temperature_log_sigma_square), (q_values.shape[0], 1))
        return tf.nn.softmax(q_values * temperature), temperature
    def get_params(self):
        return [self.temperature_mu, self.temperature_log_sigma_square]

# %%
MODELS_PREFIX = f"models/{type(env_).__name__}/{env_.board_size}x{env_.board_size}"
os.makedirs(MODELS_PREFIX, exist_ok=True)

# %%
qfunction, avg_rewards = load_models(env_, folder_name=MODELS_PREFIX if LOAD_FROM_MEMORY else None)

# %%
qtarget = tf.keras.models.clone_model(
    qfunction
)

# %% [markdown]
# ## Training

# %%
policy = BoltzmannPolicy()

# %%
optimizer = K.optimizers.Adam(1e-4)
optimizer_policy = keras.optimizers.Adam(1e-1)

# %%
loss_f = tf.keras.losses.MeanSquaredError()

@tf.function
def train_step(samples, qfunction, qtarget):
    with tf.GradientTape(persistent=True) as tape:
        losses = []
        for observation, action, reward, new_observation in samples:
            indexes = tf.range(tf.shape(action)[0], dtype=tf.int64)[..., None]
            q_estimate = qfunction(observation)
            action = tf.concat((indexes, action), axis=-1)
            q_obs = tf.gather_nd(q_estimate, action)[...,None]
            q_target = tf.stop_gradient(reward + GAMMA * tf.reduce_max(qtarget(new_observation), axis=-1)[...,None])
            losses.append(loss_f(q_target, q_obs))
        loss = tf.reduce_mean(losses)
    gradient_q = tape.gradient(loss, qfunction.trainable_weights)
    optimizer.apply_gradients(zip(gradient_q, qfunction.trainable_weights))
    return loss

# %%
losses = []
avg_rewards = []
avg_params = []
avg_rewards_baseline = 0.
BETA = 0.9

# %%
# %matplotlib inline
for iteration in trange(ITERATIONS):
    if iteration % RESET_EVERY_N == 0:
        qtarget.set_weights(qfunction.get_weights())

    with tf.GradientTape() as tape:
        tape.watch(policy.get_params())
        state = env_.to_state()
        actions, temperatures = policy.sample(qfunction(env_.to_state()))
        rewards = env_.move(actions)
        avg_rewards_baseline = avg_rewards_baseline * BETA + (1-BETA) * (np.mean(rewards))
        new_state = env_.to_state()
        replay_memory.store(state, actions, rewards, new_state)
        samples = replay_memory.sample()
        loss = -tf.math.log(
            1/tf.sqrt(2 * np.pi * tf.exp(policy.temperature_log_sigma_square)) *
            tf.exp(-1/2 * tf.square(temperatures - policy.temperature_mu) / tf.exp(policy.temperature_log_sigma_square))
        ) * (rewards - avg_rewards_baseline)

    avg_params.append(np.array(policy.get_params()))
    optimizer_policy.apply_gradients(zip(
        tape.gradient(loss, policy.get_params()),
        policy.get_params()
    ))

    if len(samples) >= replay_memory.minibatch_size:
        avg_rewards.append(np.mean(rewards == env_.FRUIT_REWARD))
        loss = train_step(samples, qfunction, qtarget)
        losses.append(
            loss
        )
    N = 100
    if len(avg_rewards) % N == 0 and len(avg_rewards) > 0:
        # clear output
        clear_output(wait=True)
        points_r = np.array(avg_rewards).reshape((-1, N)).mean(axis=-1)
        points_t = np.array(losses).reshape((-1, N)).mean(axis=-1)
        fig, axs = plt.subplots(1,3, figsize=(15,3))
        axs[0].plot(points_r, marker=".")
        axs[0].set_xlabel("iterations")
        axs[0].set_ylabel("avg reward")
        axs[1].plot(points_t, marker=".")
        axs[1].set_xlabel("iterations")
        axs[1].set_ylabel("avg loss")

        axs[2].plot(np.array(avg_params)[:len(avg_params)//N*N][:,0].reshape((-1, N)).mean(axis=-1), marker=".")
        axs[2].set_xlabel("iterations")
        axs[2].set_ylabel("avg temperature")

        plt.show()
        # save
        with open(f"{MODELS_PREFIX}/training.txt", "w+") as file:
            json.dump(np.array(avg_rewards).tolist(), file)
        qfunction.save_weights(f"{MODELS_PREFIX}/agent")
# Out:
#  52%|███████████████████████████████████████████████████████████████████████████████████▋                                                                            | 52322/100000 [3:29:02<3:10:28,  4.17it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 28
#      26 if len(samples) >= replay_memory.minibatch_size:
#      27     avg_rewards.append(np.mean(rewards == env_.FRUIT_REWARD))
# ---> 28     loss = train_step(samples, qfunction, qtarget)
#      29     losses.append(
#      30         loss
#      31     )
#      32 N = 100
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ml-apple-metal/lib/python3.9/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ml-apple-metal/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ml-apple-metal/lib/python3.9/site-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ml-apple-metal/lib/python3.9/site-packages/tensorflow/python/eager/function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ml-apple-metal/lib/python3.9/site-packages/tensorflow/python/eager/function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ml-apple-metal/lib/python3.9/site-packages/tensorflow/python/eager/function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/ml-apple-metal/lib/python3.9/site-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
 N=200
avg_rewards = avg_rewards[:len(avg_rewards)//N*N]
losses = losses[:len(losses)//N*N]
points_r = np.array(avg_rewards).reshape((-1, N)).mean(axis=-1)
points_t = np.array(losses).reshape((-1, N)).mean(axis=-1)
fig, axs = plt.subplots(1,2, figsize=(12,3), dpi=200)
plt.rcParams['text.usetex'] = False
x = np.arange(len(points_r)) * N
axs[0].plot(x, points_r, marker=".")
axs[0].set_xlabel("iterations")
axs[0].set_ylabel("% of cherries eaten in 1000 boards")
axs[1].plot(x, points_t, marker=".")
axs[1].set_xlabel("iterations")
axs[1].set_ylabel("avg loss Q-R+gamma*maxQ")
plt.show()

# %% [markdown]
#  ### Random policy reward

# %%
random_env = get_env(1000)
random_rewards = []

for _ in trange(1000):
    #sample actions
    actions =  tf.random.categorical(tf.math.log(tf.convert_to_tensor([[.25]*4]*random_env.n_boards)), 1, dtype=tf.int32)
    # MDP update
    rewards = random_env.move(actions)
    random_rewards.append(np.mean(rewards == env_.FRUIT_REWARD))
# Out:
# 100%|██████████| 1000/1000 [00:16<00:00, 61.24it/s]

# %% [markdown]
# ## Training evaluation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
CHUNK_SIZE = 200
N = len(avg_rewards)//CHUNK_SIZE*CHUNK_SIZE
x = np.linspace(0,CHUNK_SIZE*N, N//CHUNK_SIZE)
plt.plot(x, np.array(random_rewards[700:]).mean(axis=-1).repeat(N//CHUNK_SIZE), marker="o")
points = np.array(avg_rewards)[:N].reshape((-1, CHUNK_SIZE)).mean(axis=-1)
plt.plot(x, points, marker=".")
_ = plt.xlabel("iterations")
_ = plt.ylabel("avg reward")
plt.legend(["random", "policy"])

# %% [markdown]
#  ## Test (graphical simulation)

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

# %%
test_env = get_env(3)

# %%
def animate(_):
    actions = policy.sample(qfunction(test_env.to_state()))
    test_env.move(actions)
    for board, image in zip(test_env.boards, images):
        image.set_data(board)
    return images

# %%
# first three are policy guided, the fourth is random, to give a comparison
fig, axs = plt.subplots(1,3, figsize=(10,5))
images = []
for b, ax in zip(test_env.boards, axs.flatten()):
    ax.get_yaxis().set_visible(False)
    ax.get_xaxis().set_visible(False)
    images.append(ax.imshow(b, origin="lower"))
anim = FuncAnimation(fig, animate, interval=30)
# Out:
# <div id='af87b87c-339a-4f8b-8904-9a27cd5cc712'></div>
